# %%
pip install virtualenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\laksh\Downloads\Pan India\archive (1)\Panindia_1.csv")

# %%
df
# Out:
#     Unnamed: 0  year  Fertility_Rate Growth_Rate
# 0            0  2024           2.122     -0.790%
# 1            1  2023           2.139     -0.930%
# 2            2  2022           2.159     -0.920%
# 3            3  2021           2.179     -0.950%
# 4            4  2020           2.200     -0.900%
# ..         ...   ...             ...         ...
# 70          70  1954           5.902     -0.020%
# 71          71  1953           5.903     -0.020%
# 72          72  1952           5.904     -0.030%
# 73          73  1951           5.906     -0.020%
# 74          74  1950           5.907      0.000%
#
# [75 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  year  Fertility_Rate Growth_Rate
# 0           0  2024           2.122     -0.790%
# 1           1  2023           2.139     -0.930%
# 2           2  2022           2.159     -0.920%
# 3           3  2021           2.179     -0.950%
# 4           4  2020           2.200     -0.900%

# %%
df.tail()
# Out:
#     Unnamed: 0  year  Fertility_Rate Growth_Rate
# 70          70  1954           5.902     -0.020%
# 71          71  1953           5.903     -0.020%
# 72          72  1952           5.904     -0.030%
# 73          73  1951           5.906     -0.020%
# 74          74  1950           5.907      0.000%

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'Fertility_Rate', 'Growth_Rate'], dtype='object')

# %%
df.isnull()
# Out:
#     Unnamed: 0   year  Fertility_Rate  Growth_Rate
# 0        False  False           False        False
# 1        False  False           False        False
# 2        False  False           False        False
# 3        False  False           False        False
# 4        False  False           False        False
# ..         ...    ...             ...          ...
# 70       False  False           False        False
# 71       False  False           False        False
# 72       False  False           False        False
# 73       False  False           False        False
# 74       False  False           False        False
#
# [75 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      75 non-null     int64
#  1   year            75 non-null     int64
#  2   Fertility_Rate  75 non-null     float64
#  3   Growth_Rate     75 non-null     object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0         year  Fertility_Rate
# count   75.000000    75.000000       75.000000
# mean    37.000000  1987.000000        4.234800
# std     21.794495    21.794495        1.372041
# min      0.000000  1950.000000        2.122000
# 25%     18.500000  1968.500000        2.968000
# 50%     37.000000  1987.000000        4.349000
# 75%     55.500000  2005.500000        5.691500
# max     74.000000  2024.000000        5.907000

# %%
df.mean(numeric_only=True)
# Out:
# Unnamed: 0          37.0000
# year              1987.0000
# Fertility_Rate       4.2348
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Unnamed: 0          37.000
# year              1987.000
# Fertility_Rate       4.349
# dtype: float64

# %%
df.nunique()
# Out:
# Unnamed: 0        75
# year              75
# Fertility_Rate    75
# Growth_Rate       58
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Unique Values in Pan India')
plt.plot(df.nunique())
plt.show()

# %%
plt.plot(df.mean())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.plot(df.mean())
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...

# %%
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Description of Pan India')
plt.plot(df.describe(),color = 'green',lw=2.5,ls = '-.')
plt.plot([1,2,3,4,5], [1,4,9,16, 25], color = 'red', lw = 2.5, marker = '^', mec = 'blue', mew = 5)
plt.show()

# %%
plt.plot(df.info())
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      75 non-null     int64
#  1   year            75 non-null     int64
#  2   Fertility_Rate  75 non-null     float64
#  3   Growth_Rate     75 non-null     object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.5+ KB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 plt.plot(df.info())
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# ...

# %%
plt.plot(df.head())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1822, in Axis.convert_units(self, x)
#    1821 try:
# -> 1822     ret = self._converter.convert(x, self.units, self)
#    1823 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.plot(df.tail())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1822, in Axis.convert_units(self, x)
#    1821 try:
# -> 1822     ret = self._converter.convert(x, self.units, self)
#    1823 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.plot(df.median())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 plt.plot(df.median())
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11706, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11698 @doc(make_doc("median", ndim=2))
#   11699 def median(
#   11700     self,
#    (...)
#   11704     **kwargs,
#   11705 ):
# > 11706     result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707     if isinstance(result, Series):
#   11708         result = result.__finalize__(self, method="median")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
#   12430 ) -> Series | float:
# ...

# %%
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Null Value Finder')
plt.plot(df.isnull())
plt.show()

# %%
a=5
b=8
plt.plot(a,b)

# %%
x1=a
y1=b
plt.plot(x1,y1)
plt.show()

# %%
c=b-2
d=a-3
plt.plot(c,d)
plt.show()

# %%
e=c+1
f=d+1
plt.plot(e,f)
plt.show()

# %%
g=e-2
h=f+5
plt.plot(g,h)
plt.show()

# %%
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Calculation')
# Out:
# Text(0.5, 1.0, 'Calculation')

# %%
x1 = np.linspace(-np.pi, np.pi, 256)
x2 = np.linspace(-np.pi, np.pi, 256)

y1 = np.cos(x1)
y2 = np.sin(x2)

# %%
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
plt.figure(figsize = (15, 10), dpi = 90)
plt.plot(x1, y1)
plt.plot(x2, y2)

plt.show()

# %%
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Graph of X and Y')
plt.plot(x1,y1)
plt.show()

# %%
a=3
b=1
c=3d
plt.plot(a,b,c)
plt.show()

# %%
d=a+1
e=b+1
f=c+1
plt.plot(d,e,f)
plt.show()

# %%
h=d-1+e-2+f-3
plt.plot(h)
plt.show()

# %%
i=d-3+e-1+f-2
plt.plot(i)
plt.show()
j=i+2
plt.plot(j)
plt.show()
plt.plot(h+j)
plt.show()

# %%
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Generation Graph')
plt.plot(a,b)
plt.show()

# %%
a=5
b=5
c=5
d=5
e=5
f=5
plt.plot(a+b+c+d+e+f)
plt.show()

# %%
a=5-2
plt.plot(a)
plt.show()

# %%
b=5-1
plt.plot(b)
plt.show()

# %%
c=5
plt.plot(c)
plt.show()

# %%
d=5+2-3
plt.plot(d)
plt.show()

# %%
plt.plot(a+b+c+d)
plt.show()

# %%
g=1+3
plt.plot(g)
plt.plot(a+b+c+d+g)
plt.show()

# %%
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Mark Graph')
plt.plot(a,b)
plt.show()

# %%
plt.figure(figsize = (10, 6), dpi = 80)

plt.plot( 'purple')
plt.plot(x2, y2, color = 'green')

plt.show()

# %%
plt.figure(figsize = (10,6), dpi = 80)

plt.plot([11,12,13,14,15], [30,23,19,15,5], color = 'red', lw = 2.5, marker = '^', mec = 'blue', mew = 5)
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Graph')
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.plot(x1, y1, 'r')

plt.subplot(1,2,2)
plt.plot(x2, y2, 'b-.')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Graph')
plt.show()

# %%
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Graph')
plt.show()
