# %%
pip install virtualenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
a=3
b=1
c=3
d=a+1
e=b+1
f=c+1
print(d)
print(e)
print(f)
h=d-1+e-2+f-3
print(h)
i=d-3+e-1+f-2
print(i)
j=i+2
print(j)
print(h+j)
# Out:
# 4
# 2
# 4
# 4
# 4
# 6
# 10

# %%
a=5
b=8
c=b-2
d=a-3
print(c,d)
e=c+1
f=d+1
print(e,f)
g=e-2
h=f+5
print(g,h)
# Out:
# 6 2
# 7 3
# 5 8

# %%
a=2
b=4
c=a+b
print("The sum of a and b is:", c)
# Out:
# The sum of a and b is: 6

# %%
a=5
b=5
c=5
d=5
e=5
f=5
print(a+b+c+d+e+f)
a=5-2
print(a)
b=5-1
print(b)
c=5
print(c)
d=5+2-3
print(d)
print(a+b+c+d)
g=1+3
print(g)
print(a+b+c+d+g)
# Out:
# 30
# 3
# 4
# 5
# 4
# 16
# 4
# 20

# %%
a=8
r=a/3
print(r)
# Out:
# 2.6666666666666665

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
df=pd.read_csv(r"C:\Users\laksh\Downloads\Language\archive (1)\languages_dataset.csv")

# %%
df
# Out:
#              Language         Family            Region   Speakers  \
# 0              Yoruba  Indo-European             India   76000000
# 1        Southern Min  Indo-European             India   47000000
# 2     Yue (Cantonese)      Dravidian             India   75000000
# 3             Spanish   Austronesian            Poland   76900000
# 4              Arabic  Indo-European         Worldwide   76000000
# ..                ...            ...               ...        ...
# 495           Punjabi   Indo-Iranian             India   23000000
# 496           Spanish      Dravidian         Worldwide   76900000
# 497           English  Indo-European  Germany, Austria   28000000
# 498  Xiang (Hunanese)  Indo-European         Worldwide  460000000
# 499           Punjabi  Indo-European         Indonesia   83000000
#
#     Writing System ISO Code
# 0            Latin       om
# 1            Latin       ru
# 2       Devanagari       my
# 3       Devanagari       it
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Language        500 non-null    object
#  1   Family          500 non-null    object
#  2   Region          500 non-null    object
#  3   Speakers        500 non-null    int64
#  4   Writing System  500 non-null    object
#  5   ISO Code        489 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 23.6+ KB

# %%
df.describe()
# Out:
#            Speakers
# count  5.000000e+02
# mean   9.840200e+07
# std    1.414893e+08
# min    2.000000e+07
# 25%    2.800000e+07
# 50%    5.350000e+07
# 75%    7.690000e+07
# max    9.180000e+08

# %%
df.head()
# Out:
#           Language         Family     Region  Speakers Writing System ISO Code
# 0           Yoruba  Indo-European      India  76000000          Latin       om
# 1     Southern Min  Indo-European      India  47000000          Latin       ru
# 2  Yue (Cantonese)      Dravidian      India  75000000     Devanagari       my
# 3          Spanish   Austronesian     Poland  76900000     Devanagari       it
# 4           Arabic  Indo-European  Worldwide  76000000         Hangul       ur

# %%
df.tail()
# Out:
#              Language         Family            Region   Speakers  \
# 495           Punjabi   Indo-Iranian             India   23000000
# 496           Spanish      Dravidian         Worldwide   76900000
# 497           English  Indo-European  Germany, Austria   28000000
# 498  Xiang (Hunanese)  Indo-European         Worldwide  460000000
# 499           Punjabi  Indo-European         Indonesia   83000000
#
#     Writing System ISO Code
# 495          Latin       ha
# 496          Tamil       bn
# 497          Latin      hak
# 498        Kannada       pa
# 499   Perso-Arabic       de

# %%
df=pd.read_csv(r"C:\Users\laksh\Downloads\Animals\archive (1)\class.csv")

# %%
df
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class    Class_Type  \
# 0             1                                 41        Mammal
# 1             2                                 20          Bird
# 2             3                                  5       Reptile
# 3             4                                 13          Fish
# 4             5                                  4     Amphibian
# 5             6                                  8           Bug
# 6             7                                 10  Invertebrate
#
#                                         Animal_Names
# 0  aardvark, antelope, bear, boar, buffalo, calf,...
# 1  chicken, crow, dove, duck, flamingo, gull, haw...
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                             frog, frog, newt, toad
# 5  flea, gnat, honeybee, housefly, ladybird, moth...
# 6  clam, crab, crayfish, lobster, octopus, scorpi...

# %%
df.columns
# Out:
# Index(['Class_Number', 'Number_Of_Animal_Species_In_Class', 'Class_Type',
#        'Animal_Names'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Class_Number                         7
# Number_Of_Animal_Species_In_Class    7
# Class_Type                           7
# Animal_Names                         7
# dtype: int64

# %%
df.isnull()
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class  Class_Type  Animal_Names
# 0         False                              False       False         False
# 1         False                              False       False         False
# 2         False                              False       False         False
# 3         False                              False       False         False
# 4         False                              False       False         False
# 5         False                              False       False         False
# 6         False                              False       False         False

# %%
df.mean(numeric_only= True)
# Out:
# Class_Number                          4.000000
# Number_Of_Animal_Species_In_Class    14.428571
# dtype: float64

# %%
df.median(numeric_only= True)
# Out:
# Class_Number                          4.0
# Number_Of_Animal_Species_In_Class    10.0
# dtype: float64

# %%
df.head()
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class Class_Type  \
# 0             1                                 41     Mammal
# 1             2                                 20       Bird
# 2             3                                  5    Reptile
# 3             4                                 13       Fish
# 4             5                                  4  Amphibian
#
#                                         Animal_Names
# 0  aardvark, antelope, bear, boar, buffalo, calf,...
# 1  chicken, crow, dove, duck, flamingo, gull, haw...
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                             frog, frog, newt, toad

# %%
df.tail()
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class    Class_Type  \
# 2             3                                  5       Reptile
# 3             4                                 13          Fish
# 4             5                                  4     Amphibian
# 5             6                                  8           Bug
# 6             7                                 10  Invertebrate
#
#                                         Animal_Names
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                             frog, frog, newt, toad
# 5  flea, gnat, honeybee, housefly, ladybird, moth...
# 6  clam, crab, crayfish, lobster, octopus, scorpi...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Class_Number                       7 non-null      int64
#  1   Number_Of_Animal_Species_In_Class  7 non-null      int64
#  2   Class_Type                         7 non-null      object
#  3   Animal_Names                       7 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 356.0+ bytes

# %%
df.describe()
# Out:
#        Class_Number  Number_Of_Animal_Species_In_Class
# count      7.000000                           7.000000
# mean       4.000000                          14.428571
# std        2.160247                          12.895182
# min        1.000000                           4.000000
# 25%        2.500000                           6.500000
# 50%        4.000000                          10.000000
# 75%        5.500000                          16.500000
# max        7.000000                          41.000000

# %%
df=pd.read_csv(r"C:\Users\laksh\Downloads\Animals\archive (1)\zoo.csv")

# %%
df
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
# ...

# %%
df.describe()
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    backbone    breathes    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# ...

# %%
df.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    class_type
# 0           1
# 1           1
# 2           4
# ...

# %%
df.tail()
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# 96         1         1         1         0     0     2     1         0
# 97         0         0         1         1     0     6     0         0
# 98         1         1         1         0     0     4     1         0
# 99         0         0         1         0     0     0     0         0
# 100        0         1         1         0     0     2     1         0
#
#      catsize  class_type
# 96         1           1
# 97         0           6
# ...

# %%
df.isnull()
# Out:
#      animal_name   hair  feathers   eggs   milk  airborne  aquatic  predator  \
# 0          False  False     False  False  False     False    False     False
# 1          False  False     False  False  False     False    False     False
# 2          False  False     False  False  False     False    False     False
# 3          False  False     False  False  False     False    False     False
# 4          False  False     False  False  False     False    False     False
# ..           ...    ...       ...    ...    ...       ...      ...       ...
# 96         False  False     False  False  False     False    False     False
# 97         False  False     False  False  False     False    False     False
# 98         False  False     False  False  False     False    False     False
# 99         False  False     False  False  False     False    False     False
# 100        False  False     False  False  False     False    False     False
#
# ...

# %%
df.nunique()
# Out:
# animal_name    100
# hair             2
# feathers         2
# eggs             2
# milk             2
# airborne         2
# aquatic          2
# predator         2
# toothed          2
# backbone         2
# breathes         2
# venomous         2
# fins             2
# legs             6
# tail             2
# domestic         2
# catsize          2
# class_type       7
# dtype: int64

# %%
df.median(numeric_only= True)
# Out:
# hair          0.0
# feathers      0.0
# eggs          1.0
# milk          0.0
# airborne      0.0
# aquatic       0.0
# predator      1.0
# toothed       1.0
# backbone      1.0
# breathes      1.0
# venomous      0.0
# fins          0.0
# legs          4.0
# tail          1.0
# domestic      0.0
# catsize       0.0
# class_type    2.0
# dtype: float64

# %%
df.mean(numeric_only= True)
# Out:
# hair          0.425743
# feathers      0.198020
# eggs          0.584158
# milk          0.405941
# airborne      0.237624
# aquatic       0.356436
# predator      0.554455
# toothed       0.603960
# backbone      0.821782
# breathes      0.792079
# venomous      0.079208
# fins          0.168317
# legs          2.841584
# tail          0.742574
# domestic      0.128713
# catsize       0.435644
# class_type    2.831683
# dtype: float64

# %%
df.columns
# Out:
# Index(['animal_name', 'hair', 'feathers', 'eggs', 'milk', 'airborne',
#        'aquatic', 'predator', 'toothed', 'backbone', 'breathes', 'venomous',
#        'fins', 'legs', 'tail', 'domestic', 'catsize', 'class_type'],
#       dtype='object')

# %%
df=pd.read_csv(r"C:\Users\laksh\Downloads\Birds\archive (1)\BirdSpecies_dataset.csv")

# %%
df
# Out:
#        BodyLength  Wingspan  Weight  PlumageColorHead  PlumageColorBack  \
# 0           5.210     9.746   5.815             8.831             1.580
# 1           2.275     2.496   6.104             1.692             0.856
# 2           5.927     1.357   5.936             9.536             1.820
# 3           6.022     6.402   3.772             2.884             8.638
# 4           7.816     8.374   0.155             4.262             8.726
# ...           ...       ...     ...               ...               ...
# 24995       1.254     7.149   2.825             7.918             9.555
# 24996       0.839     2.453   3.707             4.084             1.251
# 24997       5.660     3.032   2.401             6.968             2.762
# 24998       3.230     4.500   6.235             2.701             2.794
# 24999       1.668     6.019   4.042             3.841             0.800
#
#        PlumageColorBelly  PlumageColorWings  PlumageColorTail  BeakLength  \
# ...

# %%
df.head()
# Out:
#    BodyLength  Wingspan  Weight  PlumageColorHead  PlumageColorBack  \
# 0       5.210     9.746   5.815             8.831             1.580
# 1       2.275     2.496   6.104             1.692             0.856
# 2       5.927     1.357   5.936             9.536             1.820
# 3       6.022     6.402   3.772             2.884             8.638
# 4       7.816     8.374   0.155             4.262             8.726
#
#    PlumageColorBelly  PlumageColorWings  PlumageColorTail  BeakLength  \
# 0              2.257              6.399             3.746       7.541
# 1              2.056              0.110             1.277       8.491
# 2              7.886              8.658             4.401       5.786
# 3              4.623              2.129             1.352       9.475
# 4              2.452              1.046             7.110       5.689
#
#    BeakWidth  ...  SeedDispersalRole  InterspecificInteraction  \
# 0      4.286  ...              8.122                     7.139
# ...

# %%
df.tail()
# Out:
#        BodyLength  Wingspan  Weight  PlumageColorHead  PlumageColorBack  \
# 24995       1.254     7.149   2.825             7.918             9.555
# 24996       0.839     2.453   3.707             4.084             1.251
# 24997       5.660     3.032   2.401             6.968             2.762
# 24998       3.230     4.500   6.235             2.701             2.794
# 24999       1.668     6.019   4.042             3.841             0.800
#
#        PlumageColorBelly  PlumageColorWings  PlumageColorTail  BeakLength  \
# 24995              0.723              3.481             6.203       4.350
# 24996              6.908              3.673             7.989       7.169
# 24997              3.947              8.953             3.312       9.513
# 24998              8.908              6.133             3.766       8.113
# 24999              8.178              4.550             3.264       5.055
#
#        BeakWidth  ...  SeedDispersalRole  InterspecificInteraction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 61 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   BodyLength                25000 non-null  float64
#  1   Wingspan                  25000 non-null  float64
#  2   Weight                    25000 non-null  float64
#  3   PlumageColorHead          25000 non-null  float64
#  4   PlumageColorBack          25000 non-null  float64
#  5   PlumageColorBelly         25000 non-null  float64
#  6   PlumageColorWings         25000 non-null  float64
#  7   PlumageColorTail          25000 non-null  float64
#  8   BeakLength                25000 non-null  float64
#  9   BeakWidth                 25000 non-null  float64
#  10  BeakShape                 25000 non-null  float64
#  11  BeakColor                 25000 non-null  float64
#  12  LegLength                 25000 non-null  float64
# ...

# %%
df.describe()
# Out:
#          BodyLength      Wingspan        Weight  PlumageColorHead  \
# count  25000.000000  25000.000000  25000.000000      25000.000000
# mean       5.027980      4.991811      4.968451          4.981052
# std        2.879286      2.896154      2.896407          2.886239
# min        0.000000      0.000000      0.000000          0.000000
# 25%        2.538000      2.464000      2.450000          2.478000
# 50%        5.050000      5.026000      4.937000          4.985000
# 75%        7.528250      7.479000      7.481000          7.457000
# max       10.000000     10.000000     10.000000          9.999000
#
#        PlumageColorBack  PlumageColorBelly  PlumageColorWings  \
# count      25000.000000       25000.000000       25000.000000
# mean           5.039656           5.044007           4.998379
# std            2.890039           2.892905           2.897420
# min            0.000000           0.000000           0.000000
# ...

# %%
df.isnull()
# Out:
#        BodyLength  Wingspan  Weight  PlumageColorHead  PlumageColorBack  \
# 0           False     False   False             False             False
# 1           False     False   False             False             False
# 2           False     False   False             False             False
# 3           False     False   False             False             False
# 4           False     False   False             False             False
# ...           ...       ...     ...               ...               ...
# 24995       False     False   False             False             False
# 24996       False     False   False             False             False
# 24997       False     False   False             False             False
# 24998       False     False   False             False             False
# 24999       False     False   False             False             False
#
#        PlumageColorBelly  PlumageColorWings  PlumageColorTail  BeakLength  \
# ...

# %%
df.nunique()
# Out:
# BodyLength           9175
# Wingspan             9159
# Weight               9194
# PlumageColorHead     9163
# PlumageColorBack     9203
#                      ...
# ParentalCareLevel    9137
# BathingBehavior      9215
# GroomingBehavior     9190
# FlightSpeed          9145
# SpeciesClass            6
# Length: 61, dtype: int64

# %%
df.mean(numeric_only= True)
# Out:
# BodyLength                  5.027980
# Wingspan                    4.991811
# Weight                      4.968451
# PlumageColorHead            4.981052
# PlumageColorBack            5.039656
# PlumageColorBelly           5.044007
# PlumageColorWings           4.998379
# PlumageColorTail            4.995770
# BeakLength                  5.010424
# BeakWidth                   4.993987
# BeakShape                   5.006950
# BeakColor                   5.022406
# LegLength                   5.008460
# LegColor                    4.966283
# FootType                    5.003484
# EyeColor                    5.009727
# DietType                    5.023184
# FeedingBehavior             4.981341
# PreferredHabitat            5.018826
# GeographicalRange           4.985287
# MigratoryBehavior           5.005691
# BreedingSeason              5.013654
# NestType                    5.019000
# ClutchSize                  5.044584
# EggColor                    4.970516
# ...

# %%
df.median(numeric_only= True)
# Out:
# BodyLength                  5.0500
# Wingspan                    5.0260
# Weight                      4.9370
# PlumageColorHead            4.9850
# PlumageColorBack            5.0625
# PlumageColorBelly           5.0695
# PlumageColorWings           5.0050
# PlumageColorTail            4.9620
# BeakLength                  5.0230
# BeakWidth                   4.9890
# BeakShape                   5.0155
# BeakColor                   5.0240
# LegLength                   5.0035
# LegColor                    4.9630
# FootType                    4.9925
# EyeColor                    5.0110
# DietType                    5.0270
# FeedingBehavior             5.0110
# PreferredHabitat            5.0010
# GeographicalRange           4.9685
# MigratoryBehavior           5.0080
# BreedingSeason              5.0155
# NestType                    5.0415
# ClutchSize                  5.0430
# EggColor                    4.9460
# IncubationPeriod            5.0150
# FledglingPeriod             5.0230
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df= pd.read_csv(r"C:\Users\laksh\Downloads\Companies\archive (1)\company_data.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\laksh\Downloads\Companies\archive (1)\company_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df= pd.read_csv(r"C:\Users\laksh\Downloads\Companies\archive (1)\company_data.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df=pd.read_csv(r"C:\Users\laksh\Downloads\Companies\archive (1)\company_data_v3.csv")

# %%
df
# Out:
#                                     name_of_the_company  employees_count  \
# 0                                                Amazon          1541000
# 1                                       INDIAN RAILWAYS          1308000
# 2                                            Tata Group          1028000
# 3      China Postal Express & Logistics Company Limited           927000
# 4                                                SEIDOR           900000
# ...                                                 ...              ...
# 32591                                        Cue Health             1000
# 32592               Davidson Kempner Capital Management             1000
# 32593                                              DEYA             1000
# 32594                                              Pace             1000
# 32595                       K.D. Feddersen Distribution             1000
#
#        founded_year                               current_technologies  \
# ...

# %%
df.head()
# Out:
#                                 name_of_the_company  employees_count  \
# 0                                            Amazon          1541000
# 1                                   INDIAN RAILWAYS          1308000
# 2                                        Tata Group          1028000
# 3  China Postal Express & Logistics Company Limited           927000
# 4                                            SEIDOR           900000
#
#    founded_year                               current_technologies  \
# 0        1994.0  ["AT Internet","Adobe Media Optimizer","Amazon...
# 1        1853.0  ["Apache","Bootstrap Framework","Facebook Logi...
# 2        1868.0  ["Adobe CQ","Amazon AWS","Amazon SES","Angular...
# 3        1985.0          ["Bootstrap Framework","Mobile Friendly"]
# 4        1982.0  ["Basis","CloudFlare CDN","CloudFlare Hosting"...
#
#    annual_revenue        country  \
# 0    538046000000  United States
# 1        18835000  United States
# 2    128000000000          India
# ...

# %%
df.tail()
# Out:
#                        name_of_the_company  employees_count  founded_year  \
# 32591                           Cue Health             1000        2010.0
# 32592  Davidson Kempner Capital Management             1000        1983.0
# 32593                                 DEYA             1000        1953.0
# 32594                                 Pace             1000        2006.0
# 32595          K.D. Feddersen Distribution             1000        1949.0
#
#                                     current_technologies  annual_revenue  \
# 32591  ["Adobe Marketing Cloud","Bing Ads","Datadog",...       328831000
# 32592  ["AI","Apache","CSC Corporate Domains","Google...        75000000
# 32593  ["Bootstrap Framework","Google Analytics","Mic...       150000000
# 32594  ["Amazon AWS","Amazon CloudFront","Amazon Elas...        32835000
# 32595  ["Apache","Bootstrap Framework","Disqus","Goog...       119999840
#
#               country                                           keywords  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32596 entries, 0 to 32595
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name_of_the_company   32592 non-null  object
#  1   employees_count       32596 non-null  int64
#  2   founded_year          28555 non-null  float64
#  3   current_technologies  32596 non-null  object
#  4   annual_revenue        32596 non-null  int64
#  5   country               32406 non-null  object
#  6   keywords              32596 non-null  object
#  7   short_description     30968 non-null  object
#  8   total_funding         2641 non-null   float64
#  9   latest_funding_stage  3051 non-null   object
#  10  primary_industry      32012 non-null  object
#  11  industries            29017 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 3.0+ MB

# %%
df.describe()
# Out:
#        employees_count  founded_year  annual_revenue  total_funding
# count     3.259600e+04  28555.000000    3.259600e+04   2.641000e+03
# mean      7.785566e+03   1963.016459    3.358434e+09   6.289988e+08
# std       3.167543e+04     52.901397    2.322425e+10   2.572420e+09
# min       1.000000e+03   1501.000000    1.000000e+03   1.500000e+03
# 25%       1.400000e+03   1943.000000    7.547625e+07   1.350000e+07
# 50%       2.200000e+03   1980.000000    3.100822e+08   8.500000e+07
# 75%       5.000000e+03   2000.000000    1.000000e+09   4.190000e+08
# max       1.541000e+06   2023.000000    8.904000e+11   6.550000e+10

# %%
df.columns
# Out:
# Index(['name_of_the_company', 'employees_count', 'founded_year',
#        'current_technologies', 'annual_revenue', 'country', 'keywords',
#        'short_description', 'total_funding', 'latest_funding_stage',
#        'primary_industry', 'industries'],
#       dtype='object')

# %%
df.mean(numeric_only= True)
# Out:
# employees_count    7.785566e+03
# founded_year       1.963016e+03
# annual_revenue     3.358434e+09
# total_funding      6.289988e+08
# dtype: float64

# %%
df.median(numeric_only= True)
# Out:
# employees_count         2200.0
# founded_year            1980.0
# annual_revenue     310082240.0
# total_funding       85000000.0
# dtype: float64

# %%
df.isnull()
# Out:
#        name_of_the_company  employees_count  founded_year  \
# 0                    False            False         False
# 1                    False            False         False
# 2                    False            False         False
# 3                    False            False         False
# 4                    False            False         False
# ...                    ...              ...           ...
# 32591                False            False         False
# 32592                False            False         False
# 32593                False            False         False
# 32594                False            False         False
# 32595                False            False         False
#
#        current_technologies  annual_revenue  country  keywords  \
# 0                     False           False    False     False
# 1                     False           False    False     False
# 2                     False           False    False     False
# ...

# %%
df.nunique()
# Out:
# name_of_the_company     32358
# employees_count           352
# founded_year              368
# current_technologies    30243
# annual_revenue          13442
# country                   170
# keywords                22724
# short_description       30884
# total_funding            1918
# latest_funding_stage       16
# primary_industry          143
# industries                932
# dtype: int64

# %%
df= pd.read_csv(r"C:\Users\laksh\Downloads\Devices\archive (1)\smartphones.csv")

# %%
df
# Out:
#     brand_name                                      model   price  avg_rating  \
# 0        apple                            Apple iPhone 11   38999         7.3
# 1        apple                    Apple iPhone 11 (128GB)   46999         7.5
# 2        apple                    Apple iPhone 11 Pro Max  109900         7.7
# 3        apple                            Apple iPhone 12   51999         7.4
# 4        apple                    Apple iPhone 12 (128GB)   55999         7.5
# ..         ...                                        ...     ...         ...
# 975     xiaomi                    Xiaomi Redmi Note 9 Pro   13999         7.5
# 976     xiaomi  Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)   14439         7.7
# 977     xiaomi                Xiaomi Redmi Note 9 Pro Max   16490         8.0
# 978        zte                               ZTE Axon 30S   19999         8.2
# 979        zte                       ZTE Axon 40 Ultra 5G   61990         8.9
#
# ...

# %%
df.head()
# Out:
#   brand_name                    model   price  avg_rating  5G_or_not  \
# 0      apple          Apple iPhone 11   38999         7.3          0
# 1      apple  Apple iPhone 11 (128GB)   46999         7.5          0
# 2      apple  Apple iPhone 11 Pro Max  109900         7.7          0
# 3      apple          Apple iPhone 12   51999         7.4          1
# 4      apple  Apple iPhone 12 (128GB)   55999         7.5          1
#
#   processor_brand  num_cores  processor_speed  battery_capacity  \
# 0          bionic        6.0             2.65            3110.0
# 1          bionic        6.0             2.65            3110.0
# 2          bionic        6.0             2.65            3500.0
# 3          bionic        6.0             3.10               NaN
# 4          bionic        6.0             3.10               NaN
#
#    fast_charging_available  ...  internal_memory  screen_size  refresh_rate  \
# 0                        0  ...               64          6.1            60
# ...

# %%
df.tail()
# Out:
#     brand_name                                      model  price  avg_rating  \
# 975     xiaomi                    Xiaomi Redmi Note 9 Pro  13999         7.5
# 976     xiaomi  Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)  14439         7.7
# 977     xiaomi                Xiaomi Redmi Note 9 Pro Max  16490         8.0
# 978        zte                               ZTE Axon 30S  19999         8.2
# 979        zte                       ZTE Axon 40 Ultra 5G  61990         8.9
#
#      5G_or_not processor_brand  num_cores  processor_speed  battery_capacity  \
# 975          0      snapdragon        8.0              2.3            5020.0
# 976          0      snapdragon        8.0              2.3            5020.0
# 977          0      snapdragon        8.0              2.3            5020.0
# 978          1      snapdragon        8.0              3.2            4200.0
# 979          1      snapdragon        8.0              3.0            5000.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   avg_rating                 879 non-null    float64
#  4   5G_or_not                  980 non-null    int64
#  5   processor_brand            960 non-null    object
#  6   num_cores                  974 non-null    float64
#  7   processor_speed            938 non-null    float64
#  8   battery_capacity           969 non-null    float64
#  9   fast_charging_available    980 non-null    int64
#  10  fast_charging              769 non-null    float64
#  11  ram_capacity               980 non-null    int64
#  12  internal_memory            980 non-null    int64
# ...

# %%
df.describe()
# Out:
#                price  avg_rating   5G_or_not   num_cores  processor_speed  \
# count     980.000000  879.000000  980.000000  974.000000       938.000000
# mean    32520.504082    7.825825    0.560204    7.772074         2.427217
# std     39531.812669    0.740285    0.496616    0.836845         0.464090
# min      3499.000000    6.000000    0.000000    4.000000         1.200000
# 25%     12999.000000    7.400000    0.000000    8.000000         2.050000
# 50%     19994.500000    8.000000    1.000000    8.000000         2.300000
# 75%     35491.500000    8.400000    1.000000    8.000000         2.840000
# max    650000.000000    8.900000    1.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        969.000000               980.000000     769.000000    980.000000
# mean        4817.748194                 0.854082      46.126138      6.560204
# ...

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'avg_rating', '5G_or_not',
#        'processor_brand', 'num_cores', 'processor_speed', 'battery_capacity',
#        'fast_charging_available', 'fast_charging', 'ram_capacity',
#        'internal_memory', 'screen_size', 'refresh_rate', 'num_rear_cameras',
#        'os', 'primary_camera_rear', 'primary_camera_front',
#        'extended_memory_available', 'resolution_height', 'resolution_width'],
#       dtype='object')

# %%
df.mean(numeric_only= True)
# Out:
# price                        32520.504082
# avg_rating                       7.825825
# 5G_or_not                        0.560204
# num_cores                        7.772074
# processor_speed                  2.427217
# battery_capacity              4817.748194
# fast_charging_available          0.854082
# fast_charging                   46.126138
# ram_capacity                     6.560204
# internal_memory                141.036735
# screen_size                      6.536765
# refresh_rate                    92.256122
# num_rear_cameras                 2.814286
# primary_camera_rear             50.319286
# primary_camera_front            16.589744
# extended_memory_available        0.630612
# resolution_height             2214.663265
# resolution_width              1075.852041
# dtype: float64

# %%
df.median(numeric_only= True)
# Out:
# price                        19994.50
# avg_rating                       8.00
# 5G_or_not                        1.00
# num_cores                        8.00
# processor_speed                  2.30
# battery_capacity              5000.00
# fast_charging_available          1.00
# fast_charging                   33.00
# ram_capacity                     6.00
# internal_memory                128.00
# screen_size                      6.58
# refresh_rate                    90.00
# num_rear_cameras                 3.00
# primary_camera_rear             50.00
# primary_camera_front            16.00
# extended_memory_available        1.00
# resolution_height             2400.00
# resolution_width              1080.00
# dtype: float64

# %%
df.isnull()
# Out:
#      brand_name  model  price  avg_rating  5G_or_not  processor_brand  \
# 0         False  False  False       False      False            False
# 1         False  False  False       False      False            False
# 2         False  False  False       False      False            False
# 3         False  False  False       False      False            False
# 4         False  False  False       False      False            False
# ..          ...    ...    ...         ...        ...              ...
# 975       False  False  False       False      False            False
# 976       False  False  False       False      False            False
# 977       False  False  False       False      False            False
# 978       False  False  False       False      False            False
# 979       False  False  False       False      False            False
#
#      num_cores  processor_speed  battery_capacity  fast_charging_available  \
# ...

# %%
df.nunique()
# Out:
# brand_name                    46
# model                        980
# price                        379
# avg_rating                    30
# 5G_or_not                      2
# processor_brand               13
# num_cores                      3
# processor_speed               35
# battery_capacity              89
# fast_charging_available        2
# fast_charging                 32
# ram_capacity                   9
# internal_memory                8
# screen_size                   79
# refresh_rate                   6
# num_rear_cameras               4
# os                             3
# primary_camera_rear           18
# primary_camera_front          19
# extended_memory_available      2
# resolution_height             65
# resolution_width              40
# dtype: int64

# %%
df= pd.read_csv(r"C:\Users\laksh\Downloads\Transport\archive (3)\Cars_Datasets_2025.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df= pd.read_csv(r"C:\Users\laksh\Downloads\Transport\archive (3)\Cars_Datasets_2025.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df= pd.read_csv(r"C:\Users\laksh\Downloads\Transport\archive (2)\Cars_India_dataset.csv")

# %%
df
# Out:
#      Unnamed: 0          Model       Maker           Type  Seats  \
# 0            24           GT-R      Nissan     Sports Car      2
# 1            40      Scorpio-N    Mahindra            SUV      6
# 2             2         Virtus  Volkswagen          Sedan      5
# 3             9          Amaze       Honda  Compact Sedan      5
# 4             8          Amaze       Honda  Compact Sedan      5
# ..          ...            ...         ...            ...    ...
# 151          26        Magnite      Nissan    Compact SUV      5
# 152          27        Magnite      Nissan    Compact SUV      5
# 153          25        Magnite      Nissan    Compact SUV      5
# 154           0         Virtus  Volkswagen          Sedan      5
# 155         107  Kona Electric     Hyundai            SUV      5
#
#      Displacement  Length  Width  Height  Wheelbase  ...  Rear Brake Drive  \
# 0          3799.0    4710   1895    1370       2780  ...        Disc  4 WD
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      Model       Maker           Type  Seats  Displacement  \
# 0          24       GT-R      Nissan     Sports Car      2        3799.0
# 1          40  Scorpio-N    Mahindra            SUV      6        2000.0
# 2           2     Virtus  Volkswagen          Sedan      5        1498.0
# 3           9      Amaze       Honda  Compact Sedan      5        1199.0
# 4           8      Amaze       Honda  Compact Sedan      5        1199.0
#
#    Length  Width  Height  Wheelbase  ...  Rear Brake Drive Turning Radius  \
# 0    4710   1895    1370       2780  ...        Disc  4 WD           5.57
# 1    4662   1917    1857       2750  ...        Disc   2WD            NaN
# 2    4561   1752    1507       2651  ...        Drum   2WD           5.05
# 3    3995   1695    1501       2470  ...        Drum   2WD           4.70
# 4    3995   1695    1501       2470  ...        Drum   2WD           4.70
#
#   Fuel Tank Capacity Boot Space Fuel Efficiency Emission Type   Tyre Size  \
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0          Model       Maker         Type  Seats  Displacement  \
# 151          26        Magnite      Nissan  Compact SUV      5         999.0
# 152          27        Magnite      Nissan  Compact SUV      5         999.0
# 153          25        Magnite      Nissan  Compact SUV      5         999.0
# 154           0         Virtus  Volkswagen        Sedan      5         999.0
# 155         107  Kona Electric     Hyundai          SUV      5           NaN
#
#      Length  Width  Height  Wheelbase  ...  Rear Brake Drive Turning Radius  \
# 151    3994   1758    1572       2500  ...        Drum  2 WD           5.00
# 152    3994   1758    1572       2500  ...        Drum  2 WD           5.00
# 153    3994   1758    1572       2500  ...        Drum  2 WD           5.00
# 154    4561   1752    1507       2651  ...        Drum   2WD           5.05
# 155    4180   1800    1570       2600  ...        Disc   2WD           5.30
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          156 non-null    int64
#  1   Model               156 non-null    object
#  2   Maker               156 non-null    object
#  3   Type                156 non-null    object
#  4   Seats               156 non-null    int64
#  5   Displacement        155 non-null    float64
#  6   Length              156 non-null    int64
#  7   Width               156 non-null    int64
#  8   Height              156 non-null    int64
#  9   Wheelbase           156 non-null    int64
#  10  No_of_Cylinders     155 non-null    float64
#  11  Fuel                156 non-null    object
#  12  Engine Type         156 non-null    object
#  13  Transmission        155 non-null    object
#  14  Front Brake         156 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0       Seats  Displacement       Length        Width  \
# count  156.000000  156.000000    155.000000   156.000000   156.000000
# mean    77.500000    5.538462   1598.109677  4324.455128  1800.512821
# std     45.177428    1.018440    504.656969   325.767389    79.050452
# min      0.000000    2.000000    799.000000  3731.000000  1579.000000
# 25%     38.750000    5.000000   1197.000000  3995.000000  1751.500000
# 50%     77.500000    5.000000   1493.000000  4315.000000  1790.000000
# 75%    116.250000    6.000000   1999.000000  4598.000000  1855.000000
# max    155.000000    9.000000   3799.000000  5115.000000  2099.000000
#
#             Height    Wheelbase  No_of_Cylinders  Turning Radius  \
# count   156.000000   156.000000       155.000000      137.000000
# mean   1653.666667  2633.358974         3.870968        5.247080
# std     125.170559   128.228372         0.389966        0.284181
# min    1370.000000  2422.000000         3.000000        4.700000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Maker', 'Type', 'Seats', 'Displacement',
#        'Length', 'Width', 'Height', 'Wheelbase', 'No_of_Cylinders', 'Fuel',
#        'Engine Type', 'Transmission', 'Front Brake', 'Rear Brake', 'Drive',
#        'Turning Radius', 'Fuel Tank Capacity', 'Boot Space', 'Fuel Efficiency',
#        'Emission Type', 'Tyre Size', 'Variants', 'NCAP Rating'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      Unnamed: 0  Model  Maker   Type  Seats  Displacement  Length  Width  \
# 0         False  False  False  False  False         False   False  False
# 1         False  False  False  False  False         False   False  False
# 2         False  False  False  False  False         False   False  False
# 3         False  False  False  False  False         False   False  False
# 4         False  False  False  False  False         False   False  False
# ..          ...    ...    ...    ...    ...           ...     ...    ...
# 151       False  False  False  False  False         False   False  False
# 152       False  False  False  False  False         False   False  False
# 153       False  False  False  False  False         False   False  False
# 154       False  False  False  False  False         False   False  False
# 155       False  False  False  False  False          True   False  False
#
#      Height  Wheelbase  ...  Rear Brake  Drive  Turning Radius  \
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0            156
# Model                  45
# Maker                  10
# Type                    9
# Seats                   7
# Displacement           23
# Length                 31
# Width                  31
# Height                 38
# Wheelbase              24
# No_of_Cylinders         3
# Fuel                    5
# Engine Type            55
# Transmission           23
# Front Brake             1
# Rear Brake              2
# Drive                   5
# Turning Radius         18
# Fuel Tank Capacity     15
# Boot Space             34
# Fuel Efficiency        70
# Emission Type           2
# Tyre Size              28
# Variants                9
# NCAP Rating             8
# dtype: int64

# %%
df.mean(numeric_only= True)
# Out:
# Unnamed: 0              77.500000
# Seats                    5.538462
# Displacement          1598.109677
# Length                4324.455128
# Width                 1800.512821
# Height                1653.666667
# Wheelbase             2633.358974
# No_of_Cylinders          3.870968
# Turning Radius           5.247080
# Fuel Tank Capacity      48.725806
# Boot Space             377.673759
# Fuel Efficiency         18.028947
# Variants                 2.871795
# dtype: float64

# %%
df.median(numeric_only= True)
# Out:
# Unnamed: 0              77.5
# Seats                    5.0
# Displacement          1493.0
# Length                4315.0
# Width                 1790.0
# Height                1631.0
# Wheelbase             2610.0
# No_of_Cylinders          4.0
# Turning Radius           5.2
# Fuel Tank Capacity      50.0
# Boot Space             392.0
# Fuel Efficiency         18.1
# Variants                 2.0
# dtype: float64

# %%
df= pd.read_csv(r"C:\Users\laksh\Downloads\Transport\archive (1)\AirIndia_Domestic.csv")

# %%
df
# Out:
#     Month  DEPARTURES\n  HOURS\n  KILOMETER\n(TH)  PASSENGERS CARRIED\n  \
# 0     APR        8331.0  13998.0           7670.0              852743.0
# 1     MAY        8648.0  14547.0           8039.0              933573.0
# 2    JUNE        8279.0  14232.0           7367.0              809681.0
# 3    JULY        8562.0  14860.0           7725.0              803943.0
# 4     AUG        8547.0  14666.0           7756.0              908224.0
# ..    ...           ...      ...              ...                   ...
# 115   NOV        7761.0  14921.9           8586.3             1062524.0
# 116   DEC        8239.0  15839.7           9084.0             1170659.0
# 117   JAN        8295.0  16310.5           9174.5             1154581.0
# 118   FEB        7624.0  14934.6           8347.7             1076299.0
# 119   MAR           NaN      NaN              NaN                   NaN
#
#      PASSENGER KMS. PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)  \
# ...

# %%
df.head()
# Out:
#   Month  DEPARTURES\n  HOURS\n  KILOMETER\n(TH)  PASSENGERS CARRIED\n  \
# 0   APR        8331.0  13998.0           7670.0              852743.0
# 1   MAY        8648.0  14547.0           8039.0              933573.0
# 2  JUNE        8279.0  14232.0           7367.0              809681.0
# 3  JULY        8562.0  14860.0           7725.0              803943.0
# 4   AUG        8547.0  14666.0           7756.0              908224.0
#
#    PASSENGER KMS. PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)  \
# 0                        862694.0                       1219041.0
# 1                        948498.0                       1277627.0
# 2                        830542.0                       1170875.0
# 3                        822897.0                       1227813.0
# 4                        911328.0                       1232691.0
#
#     PAX. LOAD FACTOR#\n(IN %)    FY
# 0                        70.8  FY14
# 1                        74.2  FY14
# ...

# %%
df.tail()
# Out:
#     Month  DEPARTURES\n  HOURS\n  KILOMETER\n(TH)  PASSENGERS CARRIED\n  \
# 115   NOV        7761.0  14921.9           8586.3             1062524.0
# 116   DEC        8239.0  15839.7           9084.0             1170659.0
# 117   JAN        8295.0  16310.5           9174.5             1154581.0
# 118   FEB        7624.0  14934.6           8347.7             1076299.0
# 119   MAR           NaN      NaN              NaN                   NaN
#
#      PASSENGER KMS. PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)  \
# 115                       1099937.6                       1283540.4
# 116                       1214285.0                       1359169.0
# 117                       1199173.8                       1370587.0
# 118                       1117616.5                       1256131.6
# 119                             NaN                             NaN
#
#       PAX. LOAD FACTOR#\n(IN %)    FY
# 115                        85.7  FY23
# 116                        89.3  FY23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Month                          120 non-null    object
#  1   DEPARTURES
#                     119 non-null    float64
#  2   HOURS
#                          119 non-null    float64
#  3   KILOMETER
# (TH)                 119 non-null    float64
#  4   PASSENGERS CARRIED
#             119 non-null    float64
#  5   PASSENGER KMS. PERFORMED
# (TH)  119 non-null    float64
#  6   AVAILABLE SEAT KILOMETRE
# (TH)  119 non-null    float64
#  7    PAX. LOAD FACTOR#
# (IN %)      119 non-null    float64
#  8   FY                             120 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 8.6+ KB

# %%
df.describe()
# Out:
#        DEPARTURES\n       HOURS\n  KILOMETER\n(TH)  PASSENGERS CARRIED\n  \
# count    119.000000    119.000000       119.000000          1.190000e+02
# mean    8247.680672  15211.573950      8810.552941          9.892398e+05
# std     2036.087774   3772.193624      2132.725136          3.066553e+05
# min        0.000000      0.000000         0.000000          0.000000e+00
# 25%     7656.500000  14167.650000      7720.000000          8.539960e+05
# 50%     8732.000000  15493.000000      9018.000000          1.043708e+06
# 75%     9520.500000  17669.000000     10372.000000          1.229064e+06
# max    11262.000000  21297.300000     12334.100000          1.429384e+06
#
#        PASSENGER KMS. PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)  \
# count                    1.190000e+02                    1.190000e+02
# mean                     9.788782e+05                    1.269338e+06
# std                      2.855746e+05                    3.032819e+05
# ...

# %%
df.mean(numeric_only= True)
# Out:
# DEPARTURES\n                      8.247681e+03
# HOURS\n                           1.521157e+04
# KILOMETER\n(TH)                   8.810553e+03
# PASSENGERS CARRIED\n              9.892398e+05
# PASSENGER KMS. PERFORMED\n(TH)    9.788782e+05
# AVAILABLE SEAT KILOMETRE\n(TH)    1.269338e+06
#  PAX. LOAD FACTOR#\n(IN %)        7.503193e+01
# dtype: float64

# %%
df.median(numeric_only= True)
# Out:
# DEPARTURES\n                         8732.0
# HOURS\n                             15493.0
# KILOMETER\n(TH)                      9018.0
# PASSENGERS CARRIED\n              1043708.0
# PASSENGER KMS. PERFORMED\n(TH)    1015279.0
# AVAILABLE SEAT KILOMETRE\n(TH)    1291584.0
#  PAX. LOAD FACTOR#\n(IN %)             78.1
# dtype: float64

# %%
df.isnull()
# Out:
#      Month  DEPARTURES\n  HOURS\n  KILOMETER\n(TH)  PASSENGERS CARRIED\n  \
# 0    False         False    False            False                 False
# 1    False         False    False            False                 False
# 2    False         False    False            False                 False
# 3    False         False    False            False                 False
# 4    False         False    False            False                 False
# ..     ...           ...      ...              ...                   ...
# 115  False         False    False            False                 False
# 116  False         False    False            False                 False
# 117  False         False    False            False                 False
# 118  False         False    False            False                 False
# 119  False          True     True             True                  True
#
#      PASSENGER KMS. PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)  \
# ...

# %%
df.nunique()
# Out:
# Month                              12
# DEPARTURES\n                      116
# HOURS\n                           119
# KILOMETER\n(TH)                   119
# PASSENGERS CARRIED\n              119
# PASSENGER KMS. PERFORMED\n(TH)    119
# AVAILABLE SEAT KILOMETRE\n(TH)    119
#  PAX. LOAD FACTOR#\n(IN %)         99
# FY                                 10
# dtype: int64

# %%
df.columns
# Out:
# Index(['Month', 'DEPARTURES\n', 'HOURS\n', 'KILOMETER\n(TH)',
#        'PASSENGERS CARRIED\n', 'PASSENGER KMS. PERFORMED\n(TH)',
#        'AVAILABLE SEAT KILOMETRE\n(TH)', ' PAX. LOAD FACTOR#\n(IN %)', 'FY'],
#       dtype='object')

# %%
df= pd.read_csv(r"C:\Users\laksh\Downloads\Transport\archive (1)\AirIndia_International.csv")

# %%
df
# Out:
#     Month  DEPARTURES\n  HOURS\n  KILOMETRE\n(TH)  PASSENGERS CARRIED\n  \
# 0     APR        2727.0  12989.0           9552.0              394072.0
# 1     MAY        2733.0  13053.0           9868.0              415697.0
# 2    JUNE        2777.0  13339.0           9744.0              420919.0
# 3    JULY        2813.0  13430.0           9916.0              372662.0
# 4     AUG        2844.0  13731.0          10037.0              424706.0
# ..    ...           ...      ...              ...                   ...
# 115   NOV        3414.0  21624.2          16098.5              599741.0
# 116   DEC        3496.0  22396.8          16639.6              642438.0
# 117   JAN        3503.0  23025.3          17147.2              649594.0
# 118   FEB        3220.0  21208.5          15906.7              599914.0
# 119   MAR           NaN      NaN              NaN                   NaN
#
#      PASSENGER KMS.PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)  \
# ...

# %%
df.head()
# Out:
#   Month  DEPARTURES\n  HOURS\n  KILOMETRE\n(TH)  PASSENGERS CARRIED\n  \
# 0   APR        2727.0  12989.0           9552.0              394072.0
# 1   MAY        2733.0  13053.0           9868.0              415697.0
# 2  JUNE        2777.0  13339.0           9744.0              420919.0
# 3  JULY        2813.0  13430.0           9916.0              372662.0
# 4   AUG        2844.0  13731.0          10037.0              424706.0
#
#    PASSENGER KMS.PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)  \
# 0                      1705993.0                       2361391.0
# 1                      1841507.0                       2439514.0
# 2                      1848800.0                       2408821.0
# 3                      1734592.0                       2451380.0
# 4                      1983795.0                       2481327.0
#
#    PAX.LOAD FACTOR (IN %)    FY
# 0                    72.2  FY14
# 1                    75.5  FY14
# 2                    76.8  FY14
# ...

# %%
df.tail()
# Out:
#     Month  DEPARTURES\n  HOURS\n  KILOMETRE\n(TH)  PASSENGERS CARRIED\n  \
# 115   NOV        3414.0  21624.2          16098.5              599741.0
# 116   DEC        3496.0  22396.8          16639.6              642438.0
# 117   JAN        3503.0  23025.3          17147.2              649594.0
# 118   FEB        3220.0  21208.5          15906.7              599914.0
# 119   MAR           NaN      NaN              NaN                   NaN
#
#      PASSENGER KMS.PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)  \
# 115                      3251503.1                       3955215.8
# 116                      3533993.5                       4131499.3
# 117                      3680735.7                       4266836.6
# 118                      3415406.3                       3973160.5
# 119                            NaN                             NaN
#
#      PAX.LOAD FACTOR (IN %)    FY
# 115                    82.2  FY23
# 116                    85.5  FY23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Month                          120 non-null    object
#  1   DEPARTURES
#                     119 non-null    float64
#  2   HOURS
#                          119 non-null    float64
#  3   KILOMETRE
# (TH)                 119 non-null    float64
#  4   PASSENGERS CARRIED
#             119 non-null    float64
#  5   PASSENGER KMS.PERFORMED
# (TH)   119 non-null    float64
#  6   AVAILABLE SEAT KILOMETRE
# (TH)  119 non-null    float64
#  7    PAX.LOAD FACTOR (IN %)        120 non-null    object
#  8   FY                             120 non-null    object
# dtypes: float64(6), object(3)
# memory usage: 8.6+ KB

# %%
df.describe()
# Out:
#        DEPARTURES\n       HOURS\n  KILOMETRE\n(TH)  PASSENGERS CARRIED\n  \
# count    119.000000    119.000000       119.000000            119.000000
# mean    2494.428571  13968.377311     13918.952941         407992.840336
# std     1285.325010   7459.614926      7966.346966         216257.445191
# min        0.000000      0.000000         0.000000              0.000000
# 25%     2797.500000  13580.500000     10167.500000         412936.500000
# 50%     3015.000000  16176.000000     17833.000000         475964.000000
# 75%     3195.500000  19294.600000     20099.500000         544439.000000
# max     3885.000000  23025.300000     23501.000000         681323.000000
#
#        PASSENGER KMS.PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)
# count                   1.190000e+02                    1.190000e+02
# mean                    1.995407e+06                    2.573379e+06
# std                     1.096544e+06                    1.365081e+06
# ...
